# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy import stats
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 585

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url+"appid=" + weather_api_key +"&units="+units+ "&q=" + city
   
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

  # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']
        
        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})


    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | crystal city
# Processing Record 2 of Set 1 | susuman
# Processing Record 3 of Set 1 | bethel
# Processing Record 4 of Set 1 | hermanus
# Processing Record 5 of Set 1 | yuzhno-kurilsk
# Processing Record 6 of Set 1 | whitehorse
# Processing Record 7 of Set 1 | puerto ayora
# Processing Record 8 of Set 1 | el granada
# Processing Record 9 of Set 1 | college
# Processing Record 10 of Set 1 | edinburgh of the seven seas
# Processing Record 11 of Set 1 | otacilio costa
# Processing Record 12 of Set 1 | bodden town
# Processing Record 13 of Set 1 | port-aux-francais
# Processing Record 14 of Set 1 | chonchi
# Processing Record 15 of Set 1 | monte alegre
# Processing Record 16 of Set 1 | bismarck
# Processing Record 17 of Set 1 | adamstown
# Processing Record 18 of Set 1 | chinde
# Processing Record 19 of Set 1 | fortuna
# Processing Record 20 of Set 1 | isafjordur
# Processing Record 21 of Set 1 | iqaluit
# Processing Record 22 of Set 1 | ocean shores
# Processing Record 23 of Set 1 | wailua homesteads
# Processing Record 24 of Set 1 | vingt cinq
# City not found. Skipping...
# Processing Record 25 of Set 1 | waitangi
# Processing Record 26 of Set 1 | kingston
# Processing Record 27 of Set 1 | albany
# Processing Record 28 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 29 of Set 1 | lihue
# Processing Record 30 of Set 1 | shalkar
# Processing Record 31 of Set 1 | nemuro
# Processing Record 32 of Set 1 | arraial do cabo
# Processing Record 33 of Set 1 | luanda
# Processing Record 34 of Set 1 | shakawe
# Processing Record 35 of Set 1 | port elizabeth
# Processing Record 36 of Set 1 | kodiak
# Processing Record 37 of Set 1 | prieska
# Processing Record 38 of Set 1 | bengkulu
# Processing Record 39 of Set 1 | andilamena
# Processing Record 40 of Set 1 | luderitz
# Processing Record 41 of Set 1 | kourou
# Processing Record 42 of Set 1 | blackmans bay
# Processing Record 43 of Set 1 | six-fours-les-plages
# Processing Record 44 of Set 1 | avarua
# Processing Record 45 of Set 1 | bayanhongor
# Processing Record 46 of Set 1 | awjilah
# Processing Record 47 of Set 1 | novoagansk
# Processing Record 48 of Set 1 | choibalsan
# Processing Record 49 of Set 1 | yellowknife
# Processing Record 50 of Set 1 | waltham
# Processing Record 0 of Set 2 | thompson
# Processing Record 1 of Set 2 | sosnovyy bor
# Processing Record 2 of Set 2 | ilulissat
# Processing Record 3 of Set 2 | papatowai
# Processing Record 4 of Set 2 | margate
# Processing Record 5 of Set 2 | sena madureira
# Processing Record 6 of Set 2 | udachny
# Processing Record 7 of Set 2 | kaa-khem
# Processing Record 8 of Set 2 | mpanda
# Processing Record 9 of Set 2 | kotel'nich
# Processing Record 10 of Set 2 | san jose village
# City not found. Skipping...
# Processing Record 11 of Set 2 | olonkinbyen
# Processing Record 12 of Set 2 | hoxtolgay
# City not found. Skipping...
# Processing Record 13 of Set 2 | ribeira grande
# Processing Record 14 of Set 2 | belyy yar
# Processing Record 15 of Set 2 | puerto natales
# Processing Record 16 of Set 2 | anadyr
# Processing Record 17 of Set 2 | weinan
# Processing Record 18 of Set 2 | vorgashor
# Processing Record 19 of Set 2 | anabar
# City not found. Skipping...
# Processing Record 20 of Set 2 | hadibu
# Processing Record 21 of Set 2 | sinabang
# Processing Record 22 of Set 2 | victoria falls
# Processing Record 23 of Set 2 | aztec
# Processing Record 24 of Set 2 | alice springs
# Processing Record 25 of Set 2 | grytviken
# Processing Record 26 of Set 2 | kalix
# Processing Record 27 of Set 2 | dunedin
# Processing Record 28 of Set 2 | shats'k
# Processing Record 29 of Set 2 | manokwari
# Processing Record 30 of Set 2 | limon
# Processing Record 31 of Set 2 | ust-nera
# Processing Record 32 of Set 2 | invercargill
# Processing Record 33 of Set 2 | port alfred
# Processing Record 34 of Set 2 | unai
# Processing Record 35 of Set 2 | rio branco
# Processing Record 36 of Set 2 | tolanaro
# Processing Record 37 of Set 2 | eyl
# Processing Record 38 of Set 2 | sihanoukville
# Processing Record 39 of Set 2 | margaret river
# Processing Record 40 of Set 2 | polyarnyye zori
# Processing Record 41 of Set 2 | hawaiian paradise park
# Processing Record 42 of Set 2 | dompu
# Processing Record 43 of Set 2 | jwaneng
# Processing Record 44 of Set 2 | punta arenas
# Processing Record 45 of Set 2 | atar
# Processing Record 46 of Set 2 | walvis bay
# Processing Record 47 of Set 2 | khandyga
# Processing Record 48 of Set 2 | fuvahmulah
# City not found. Skipping...
# Processing Record 49 of Set 2 | saipan
# Processing Record 0 of Set 3 | ceres
# Processing Record 1 of Set 3 | mejit
# Processing Record 2 of Set 3 | lebu
# Processing Record 3 of Set 3 | hammerfest
# Processing Record 4 of Set 3 | yamada
# Processing Record 5 of Set 3 | badger
# Processing Record 6 of Set 3 | bandarbeyla
# Processing Record 7 of Set 3 | mount isa
# Processing Record 8 of Set 3 | iskateley
# Processing Record 9 of Set 3 | ushuaia
# Processing Record 10 of Set 3 | howrah
# Processing Record 11 of Set 3 | new norfolk
# Processing Record 12 of Set 3 | cururupu
# Processing Record 13 of Set 3 | rodino
# Processing Record 14 of Set 3 | cabo san lucas
# Processing Record 15 of Set 3 | keflavik
# Processing Record 16 of Set 3 | tionk essil
# Processing Record 17 of Set 3 | queenstown
# Processing Record 18 of Set 3 | stanley
# Processing Record 19 of Set 3 | kapit
# Processing Record 20 of Set 3 | weno
# Processing Record 21 of Set 3 | isangel
# Processing Record 22 of Set 3 | emerald
# Processing Record 23 of Set 3 | eilat
# Processing Record 24 of Set 3 | tazovsky
# Processing Record 25 of Set 3 | west island
# Processing Record 26 of Set 3 | korla
# Processing Record 27 of Set 3 | mangrol
# Processing Record 28 of Set 3 | armacao de buzios
# Processing Record 29 of Set 3 | nakamura
# Processing Record 30 of Set 3 | ghadamis
# Processing Record 31 of Set 3 | cadale
# Processing Record 32 of Set 3 | asifabad
# Processing Record 33 of Set 3 | derzhavinsk
# Processing Record 34 of Set 3 | bei'an
# Processing Record 35 of Set 3 | persembe
# Processing Record 36 of Set 3 | island harbour
# Processing Record 37 of Set 3 | ust-tsilma
# Processing Record 38 of Set 3 | pimentel
# Processing Record 39 of Set 3 | fort irwin
# Processing Record 40 of Set 3 | phrai bueng
# Processing Record 41 of Set 3 | devinuwara
# City not found. Skipping...
# Processing Record 42 of Set 3 | micheweni
# Processing Record 43 of Set 3 | longyearbyen
# Processing Record 44 of Set 3 | tagta
# Processing Record 45 of Set 3 | kununurra
# Processing Record 46 of Set 3 | vadso
# Processing Record 47 of Set 3 | moultonborough
# Processing Record 48 of Set 3 | enewetak
# Processing Record 49 of Set 3 | jamestown
# Processing Record 0 of Set 4 | aasiaat
# Processing Record 1 of Set 4 | saint augustine beach
# Processing Record 2 of Set 4 | samdrup jongkhar
# Processing Record 3 of Set 4 | hamilton
# Processing Record 4 of Set 4 | bikenibeu village
# Processing Record 5 of Set 4 | yueyang
# Processing Record 6 of Set 4 | bera
# Processing Record 7 of Set 4 | laguna
# Processing Record 8 of Set 4 | mildura
# Processing Record 9 of Set 4 | wynyard
# Processing Record 10 of Set 4 | taunggyi
# Processing Record 11 of Set 4 | san patricio
# Processing Record 12 of Set 4 | qarqaraly
# Processing Record 13 of Set 4 | prince george
# Processing Record 14 of Set 4 | baglung
# Processing Record 15 of Set 4 | carhuaz
# Processing Record 16 of Set 4 | wewak
# Processing Record 17 of Set 4 | meulaboh
# Processing Record 18 of Set 4 | barberton
# Processing Record 19 of Set 4 | port mathurin
# Processing Record 20 of Set 4 | sharypovo
# Processing Record 21 of Set 4 | congonhas
# Processing Record 22 of Set 4 | rongelap
# Processing Record 23 of Set 4 | alzey
# Processing Record 24 of Set 4 | sitka
# Processing Record 25 of Set 4 | kirensk
# Processing Record 26 of Set 4 | an nuhud
# Processing Record 27 of Set 4 | castillos
# Processing Record 28 of Set 4 | auki
# Processing Record 29 of Set 4 | los frentones
# Processing Record 30 of Set 4 | mawlaik
# Processing Record 31 of Set 4 | bichura
# Processing Record 32 of Set 4 | atafu village
# Processing Record 33 of Set 4 | porto novo
# Processing Record 34 of Set 4 | ocampo
# Processing Record 35 of Set 4 | sondrio
# Processing Record 36 of Set 4 | prince rupert
# Processing Record 37 of Set 4 | argo
# Processing Record 38 of Set 4 | tiksi
# Processing Record 39 of Set 4 | flying fish cove
# Processing Record 40 of Set 4 | laukaa
# Processing Record 41 of Set 4 | minas de marcona
# Processing Record 42 of Set 4 | luang prabang
# Processing Record 43 of Set 4 | klyuchi
# Processing Record 44 of Set 4 | khorinsk
# Processing Record 45 of Set 4 | deli tua
# Processing Record 46 of Set 4 | battagram
# Processing Record 47 of Set 4 | hirara
# Processing Record 48 of Set 4 | ancud
# Processing Record 49 of Set 4 | praia da vitoria
# Processing Record 0 of Set 5 | inhambane
# Processing Record 1 of Set 5 | lauro de freitas
# Processing Record 2 of Set 5 | ferkessedougou
# Processing Record 3 of Set 5 | polyarnyy
# Processing Record 4 of Set 5 | georgetown
# Processing Record 5 of Set 5 | nadvoitsy
# Processing Record 6 of Set 5 | ormara
# Processing Record 7 of Set 5 | san antonio de pale
# Processing Record 8 of Set 5 | qapqal
# City not found. Skipping...
# Processing Record 9 of Set 5 | afaahiti
# Processing Record 10 of Set 5 | sao felix do xingu
# Processing Record 11 of Set 5 | bamboo flat
# Processing Record 12 of Set 5 | touros
# Processing Record 13 of Set 5 | zag
# Processing Record 14 of Set 5 | coos bay
# Processing Record 15 of Set 5 | talnakh
# Processing Record 16 of Set 5 | dakoro
# Processing Record 17 of Set 5 | mazarron
# Processing Record 18 of Set 5 | bushehr
# Processing Record 19 of Set 5 | taltal
# Processing Record 20 of Set 5 | fengxiang
# Processing Record 21 of Set 5 | st. john's
# Processing Record 22 of Set 5 | nicoya
# Processing Record 23 of Set 5 | san fernando de apure
# Processing Record 24 of Set 5 | muntok
# Processing Record 25 of Set 5 | guanica
# Processing Record 26 of Set 5 | slavske
# Processing Record 27 of Set 5 | fonadhoo
# City not found. Skipping...
# Processing Record 28 of Set 5 | puerto baquerizo moreno
# Processing Record 29 of Set 5 | morondava
# Processing Record 30 of Set 5 | mombetsu
# Processing Record 31 of Set 5 | kolonia town
# Processing Record 32 of Set 5 | midvagur
# Processing Record 33 of Set 5 | ivins
# Processing Record 34 of Set 5 | qalat
# Processing Record 35 of Set 5 | tucuma
# Processing Record 36 of Set 5 | gassol
# Processing Record 37 of Set 5 | kyshtovka
# Processing Record 38 of Set 5 | qal'at bishah
# City not found. Skipping...
# Processing Record 39 of Set 5 | altamira
# Processing Record 40 of Set 5 | presque isle
# Processing Record 41 of Set 5 | lakatoro
# Processing Record 42 of Set 5 | altinyayla
# Processing Record 43 of Set 5 | loukhi
# Processing Record 44 of Set 5 | utrik
# Processing Record 45 of Set 5 | lillehammer
# Processing Record 46 of Set 5 | betio village
# Processing Record 47 of Set 5 | nadi
# Processing Record 48 of Set 5 | tofol
# Processing Record 49 of Set 5 | kuqa
# Processing Record 0 of Set 6 | estevan
# Processing Record 1 of Set 6 | buriti alegre
# Processing Record 2 of Set 6 | cacule
# Processing Record 3 of Set 6 | constantia
# Processing Record 4 of Set 6 | puerto san carlos
# City not found. Skipping...
# Processing Record 5 of Set 6 | bredasdorp
# Processing Record 6 of Set 6 | sabang
# Processing Record 7 of Set 6 | kavalerovo
# Processing Record 8 of Set 6 | nizhneangarsk
# Processing Record 9 of Set 6 | kismayo
# Processing Record 10 of Set 6 | vila franca do campo
# Processing Record 11 of Set 6 | antonio enes
# Processing Record 12 of Set 6 | kimbe
# Processing Record 13 of Set 6 | plast
# Processing Record 14 of Set 6 | yangor
# City not found. Skipping...
# Processing Record 15 of Set 6 | kawthoung
# City not found. Skipping...
# Processing Record 16 of Set 6 | fale old settlement
# Processing Record 17 of Set 6 | alofi
# Processing Record 18 of Set 6 | karratha
# Processing Record 19 of Set 6 | tetouan
# Processing Record 20 of Set 6 | kulia village
# City not found. Skipping...
# Processing Record 21 of Set 6 | farasan
# Processing Record 22 of Set 6 | ciudad lazaro cardenas
# Processing Record 23 of Set 6 | sisimiut
# Processing Record 24 of Set 6 | bom sucesso
# Processing Record 25 of Set 6 | harper
# Processing Record 26 of Set 6 | tarija
# Processing Record 27 of Set 6 | benghazi
# Processing Record 28 of Set 6 | zaragoza
# Processing Record 29 of Set 6 | prado
# Processing Record 30 of Set 6 | manga
# Processing Record 31 of Set 6 | bugiri
# Processing Record 32 of Set 6 | maevatanana
# City not found. Skipping...
# Processing Record 33 of Set 6 | quang ngai
# Processing Record 34 of Set 6 | satana
# Processing Record 35 of Set 6 | bilibino
# Processing Record 36 of Set 6 | yiyang
# Processing Record 37 of Set 6 | shuangjiang
# Processing Record 38 of Set 6 | santo antonio
# Processing Record 39 of Set 6 | coquimbo
# Processing Record 40 of Set 6 | tsiolkovskiy
# City not found. Skipping...
# Processing Record 41 of Set 6 | vallenar
# Processing Record 42 of Set 6 | tanrake village
# City not found. Skipping...
# Processing Record 43 of Set 6 | petropavlovsk-kamchatsky
# Processing Record 44 of Set 6 | dhidhdhoo
# Processing Record 45 of Set 6 | opuwo
# Processing Record 46 of Set 6 | isle of lewis
# City not found. Skipping...
# Processing Record 47 of Set 6 | coulounieix
# Processing Record 48 of Set 6 | taro
# Processing Record 49 of Set 6 | okha
# Processing Record 0 of Set 7 | palikir - national government center
# Processing Record 1 of Set 7 | aykhal
# Processing Record 2 of Set 7 | magadan
# Processing Record 3 of Set 7 | berezovyy
# Processing Record 4 of Set 7 | sorong
# Processing Record 5 of Set 7 | aleksandrovskoye
# Processing Record 6 of Set 7 | kathmandu
# Processing Record 7 of Set 7 | malanje
# Processing Record 8 of Set 7 | mahanje
# Processing Record 9 of Set 7 | kuldiga
# Processing Record 10 of Set 7 | port lincoln
# Processing Record 11 of Set 7 | lata
# Processing Record 12 of Set 7 | kapa'a
# Processing Record 13 of Set 7 | geraldton
# Processing Record 14 of Set 7 | toga village
# City not found. Skipping...
# Processing Record 15 of Set 7 | vilyuysk
# Processing Record 16 of Set 7 | kindu
# Processing Record 17 of Set 7 | carnarvon
# Processing Record 18 of Set 7 | gainesville
# Processing Record 19 of Set 7 | hithadhoo
# Processing Record 20 of Set 7 | lerwick
# Processing Record 21 of Set 7 | lazaro cardenas
# Processing Record 22 of Set 7 | mbale
# Processing Record 23 of Set 7 | codrington
# Processing Record 24 of Set 7 | requena
# Processing Record 25 of Set 7 | millom
# Processing Record 26 of Set 7 | mana
# Processing Record 27 of Set 7 | kodinsk
# Processing Record 28 of Set 7 | novodvinsk
# Processing Record 29 of Set 7 | eagle
# Processing Record 30 of Set 7 | las animas
# Processing Record 31 of Set 7 | vilyuchinsk
# Processing Record 32 of Set 7 | takamaka
# City not found. Skipping...
# Processing Record 33 of Set 7 | ahau
# City not found. Skipping...
# Processing Record 34 of Set 7 | bacalar
# Processing Record 35 of Set 7 | kamina
# Processing Record 36 of Set 7 | trujillo
# Processing Record 37 of Set 7 | berdigestyakh
# Processing Record 38 of Set 7 | mukah
# City not found. Skipping...
# Processing Record 39 of Set 7 | la passe
# Processing Record 40 of Set 7 | yinchuan
# Processing Record 41 of Set 7 | chadan
# Processing Record 42 of Set 7 | celestun
# Processing Record 43 of Set 7 | la'ie
# Processing Record 44 of Set 7 | salekhard
# Processing Record 45 of Set 7 | monrovia
# Processing Record 46 of Set 7 | puerto aysen
# Processing Record 47 of Set 7 | ghat
# Processing Record 48 of Set 7 | orchard homes
# Processing Record 49 of Set 7 | mitsamiouli
# Processing Record 0 of Set 8 | slave lake
# Processing Record 1 of Set 8 | tazacorte
# Processing Record 2 of Set 8 | trincomalee
# Processing Record 3 of Set 8 | tralee
# Processing Record 4 of Set 8 | pangoa
# Processing Record 5 of Set 8 | tilcara
# Processing Record 6 of Set 8 | kapuskasing
# Processing Record 7 of Set 8 | brandon
# Processing Record 8 of Set 8 | laojunmiao
# Processing Record 9 of Set 8 | nyagan
# Processing Record 10 of Set 8 | egilsstadir
# Processing Record 11 of Set 8 | uray
# Processing Record 12 of Set 8 | la ronge
# Processing Record 13 of Set 8 | santander
# Processing Record 14 of Set 8 | cargados carajos
# City not found. Skipping...
# Processing Record 15 of Set 8 | beroroha
# Processing Record 16 of Set 8 | onega
# Processing Record 17 of Set 8 | yeppoon
# Processing Record 18 of Set 8 | heniches'k
# Processing Record 19 of Set 8 | toliara
# Processing Record 20 of Set 8 | rio pardo
# Processing Record 21 of Set 8 | cestos city
# Processing Record 22 of Set 8 | burela de cabo
# Processing Record 23 of Set 8 | qaqortoq
# Processing Record 24 of Set 8 | manuguru
# Processing Record 25 of Set 8 | goulburn
# Processing Record 26 of Set 8 | bandar-e lengeh
# Processing Record 27 of Set 8 | hilo
# Processing Record 28 of Set 8 | kez
# Processing Record 29 of Set 8 | cabedelo
# Processing Record 30 of Set 8 | verdal
# Processing Record 31 of Set 8 | archangelos
# Processing Record 32 of Set 8 | saudarkrokur
# Processing Record 33 of Set 8 | goz beida
# Processing Record 34 of Set 8 | petrolina
# Processing Record 35 of Set 8 | daru
# Processing Record 36 of Set 8 | hatillo
# Processing Record 37 of Set 8 | lianzhou
# Processing Record 38 of Set 8 | marienheide
# Processing Record 39 of Set 8 | novaya igirma
# Processing Record 40 of Set 8 | qamdo
# Processing Record 41 of Set 8 | coruripe
# Processing Record 42 of Set 8 | crucecita
# Processing Record 43 of Set 8 | pak chong
# Processing Record 44 of Set 8 | maloye ganyushkino
# Processing Record 45 of Set 8 | pacific grove
# Processing Record 46 of Set 8 | elliot lake
# Processing Record 47 of Set 8 | saint-philippe
# Processing Record 48 of Set 8 | kudahuvadhoo
# Processing Record 49 of Set 8 | westport
# Processing Record 0 of Set 9 | el nido
# Processing Record 1 of Set 9 | ponta delgada
# Processing Record 2 of Set 9 | mugia
# Processing Record 3 of Set 9 | gadzhiyevo
# Processing Record 4 of Set 9 | mount gambier
# Processing Record 5 of Set 9 | gunnison
# Processing Record 6 of Set 9 | aizenay
# Processing Record 7 of Set 9 | contai
# Processing Record 8 of Set 9 | garoowe
# Processing Record 9 of Set 9 | kithor
# Processing Record 10 of Set 9 | nema
# Processing Record 11 of Set 9 | fish town
# Processing Record 12 of Set 9 | miracema do tocantins
# Processing Record 13 of Set 9 | galesong
# Processing Record 14 of Set 9 | pisco
# Processing Record 15 of Set 9 | pemangkat
# Processing Record 16 of Set 9 | kerikeri
# Processing Record 17 of Set 9 | tromso
# Processing Record 18 of Set 9 | titao
# Processing Record 19 of Set 9 | nova sintra
# Processing Record 20 of Set 9 | volokonovka
# Processing Record 21 of Set 9 | praya
# Processing Record 22 of Set 9 | al kharijah
# Processing Record 23 of Set 9 | labuan lombok
# City not found. Skipping...
# Processing Record 24 of Set 9 | 'ohonua
# City not found. Skipping...
# Processing Record 25 of Set 9 | fort st. john
# Processing Record 26 of Set 9 | mooloolaba
# Processing Record 27 of Set 9 | pariaman
# Processing Record 28 of Set 9 | akonolinga
# Processing Record 29 of Set 9 | morant bay
# Processing Record 30 of Set 9 | uaua
# Processing Record 31 of Set 9 | guerrero negro
# Processing Record 32 of Set 9 | quinhamel
# Processing Record 33 of Set 9 | murghob
# Processing Record 34 of Set 9 | pestovo
# Processing Record 35 of Set 9 | nguruka
# Processing Record 36 of Set 9 | tadine
# Processing Record 37 of Set 9 | subkhankulovo
# Processing Record 38 of Set 9 | villa gesell
# Processing Record 39 of Set 9 | turpan
# Processing Record 40 of Set 9 | maputo
# Processing Record 41 of Set 9 | catia la mar
# Processing Record 42 of Set 9 | tura
# Processing Record 43 of Set 9 | santana
# Processing Record 44 of Set 9 | siddapur
# Processing Record 45 of Set 9 | sofifi
# City not found. Skipping...
# Processing Record 46 of Set 9 | arteche
# Processing Record 47 of Set 9 | behbahan
# Processing Record 48 of Set 9 | marshalltown
# Processing Record 49 of Set 9 | belyye berega
# Processing Record 0 of Set 10 | floro
# Processing Record 1 of Set 10 | glace bay
# Processing Record 2 of Set 10 | salihli
# Processing Record 3 of Set 10 | haiku-pauwela
# Processing Record 4 of Set 10 | arica
# Processing Record 5 of Set 10 | honefoss
# Processing Record 6 of Set 10 | kalmunai
# Processing Record 7 of Set 10 | hanford
# Processing Record 8 of Set 10 | felege neway
# Processing Record 9 of Set 10 | lompoc
# Processing Record 10 of Set 10 | kavaratti
# Processing Record 11 of Set 10 | kisii
# Processing Record 12 of Set 10 | remire-montjoly
# Processing Record 13 of Set 10 | sade
# Processing Record 14 of Set 10 | franceville
# Processing Record 15 of Set 10 | kruisfontein
# Processing Record 16 of Set 10 | warmbad
# Processing Record 17 of Set 10 | valparaiso
# Processing Record 18 of Set 10 | mata-utu
# Processing Record 19 of Set 10 | newman
# Processing Record 20 of Set 10 | urangan
# Processing Record 21 of Set 10 | nakatsugawa
# Processing Record 22 of Set 10 | villa avila camacho
# Processing Record 23 of Set 10 | pontes e lacerda
# Processing Record 24 of Set 10 | shimoda
# Processing Record 25 of Set 10 | half moon bay
# Processing Record 26 of Set 10 | acarau
# Processing Record 27 of Set 10 | angaur state
# Processing Record 28 of Set 10 | ahar
# Processing Record 29 of Set 10 | nagqu
# Processing Record 30 of Set 10 | ammi moussa
# Processing Record 31 of Set 10 | taman rajawali
# City not found. Skipping...
# Processing Record 32 of Set 10 | abay
# Processing Record 33 of Set 10 | newport
# Processing Record 34 of Set 10 | llorente
# Processing Record 35 of Set 10 | tongren
# Processing Record 36 of Set 10 | crane
# Processing Record 37 of Set 10 | owensboro
# Processing Record 38 of Set 10 | port augusta
# Processing Record 39 of Set 10 | mount pearl
# Processing Record 40 of Set 10 | jayapura
# Processing Record 41 of Set 10 | wabag
# Processing Record 42 of Set 10 | lethbridge
# Processing Record 43 of Set 10 | zouerate
# Processing Record 44 of Set 10 | holualoa
# Processing Record 45 of Set 10 | thinadhoo
# Processing Record 46 of Set 10 | linjiang
# Processing Record 47 of Set 10 | inderbor
# Processing Record 48 of Set 10 | sarakhs
# Processing Record 49 of Set 10 | port hedland
# Processing Record 0 of Set 11 | shanhecun
# Processing Record 1 of Set 11 | hasaki
# Processing Record 2 of Set 11 | port macquarie
# Processing Record 3 of Set 11 | keren
# Processing Record 4 of Set 11 | raja
# Processing Record 5 of Set 11 | las khorey
# Processing Record 6 of Set 11 | san andres
# Processing Record 7 of Set 11 | manta
# Processing Record 8 of Set 11 | nahan
# Processing Record 9 of Set 11 | cooma
# Processing Record 10 of Set 11 | ta`u
# Processing Record 11 of Set 11 | kolondieba
# Processing Record 12 of Set 11 | faya-largeau
# Processing Record 13 of Set 11 | pasighat
# Processing Record 14 of Set 11 | kasongo-lunda
# Processing Record 15 of Set 11 | igarka
# Processing Record 16 of Set 11 | mahibadhoo
# Processing Record 17 of Set 11 | kavieng
# Processing Record 18 of Set 11 | port saint john's
# Processing Record 19 of Set 11 | kamensk-ural'skiy
# Processing Record 20 of Set 11 | harnai
# Processing Record 21 of Set 11 | halifax
# Processing Record 22 of Set 11 | carbonear
# Processing Record 23 of Set 11 | bembereke
# Processing Record 24 of Set 11 | bowen
# Processing Record 25 of Set 11 | deqen
# Processing Record 26 of Set 11 | penzance
# Processing Record 27 of Set 11 | nabire
# Processing Record 28 of Set 11 | xinyuan
# Processing Record 29 of Set 11 | alesund
# Processing Record 30 of Set 11 | ocos
# Processing Record 31 of Set 11 | saijo
# Processing Record 32 of Set 11 | mendoza
# Processing Record 33 of Set 11 | boca do acre
# Processing Record 34 of Set 11 | phan rang-thap cham
# Processing Record 35 of Set 11 | terrace
# Processing Record 36 of Set 11 | levuka
# Processing Record 37 of Set 11 | nelson bay
# Processing Record 38 of Set 11 | alo
# Processing Record 39 of Set 11 | ixtapa
# Processing Record 40 of Set 11 | mili
# Processing Record 41 of Set 11 | pomichna
# Processing Record 42 of Set 11 | starobin
# Processing Record 43 of Set 11 | eureka
# Processing Record 44 of Set 11 | morazan
# Processing Record 45 of Set 11 | ribeira brava
# Processing Record 46 of Set 11 | fortaleza
# Processing Record 47 of Set 11 | zheleznogorsk-ilimskiy
# Processing Record 48 of Set 11 | aldama
# Processing Record 49 of Set 11 | kholmsk
# Processing Record 0 of Set 12 | happy valley-goose bay
# Processing Record 1 of Set 12 | bay harbor
# Processing Record 2 of Set 12 | cidreira
# Processing Record 3 of Set 12 | katsuren-haebaru
# Processing Record 4 of Set 12 | kristiansund
# Processing Record 5 of Set 12 | arkalyk
# Processing Record 6 of Set 12 | mongo
# Processing Record 7 of Set 12 | callao
# Processing Record 8 of Set 12 | moratalla
# Processing Record 9 of Set 12 | kenai
# Processing Record 10 of Set 12 | colonia
# Processing Record 11 of Set 12 | sur
# Processing Record 12 of Set 12 | villa luvianos
# Processing Record 13 of Set 12 | el calafate
# Processing Record 14 of Set 12 | kalaleh
# Processing Record 15 of Set 12 | brisas de zicatela
# Processing Record 16 of Set 12 | byron bay
# Processing Record 17 of Set 12 | iquique
# Processing Record 18 of Set 12 | kirkwall
# Processing Record 19 of Set 12 | aosta
# Processing Record 20 of Set 12 | paracuru
# Processing Record 21 of Set 12 | taoudenni
# Processing Record 22 of Set 12 | garachico
# Processing Record 23 of Set 12 | marathon
# Processing Record 24 of Set 12 | lima
# Processing Record 25 of Set 12 | darhan
# Processing Record 26 of Set 12 | fort bragg
# Processing Record 27 of Set 12 | saldanha
# Processing Record 28 of Set 12 | ciudad guayana
# Processing Record 29 of Set 12 | riviere-du-loup
# Processing Record 30 of Set 12 | tsiombe
# Processing Record 31 of Set 12 | tranovaho
# City not found. Skipping...
# Processing Record 32 of Set 12 | tucumcari
# Processing Record 33 of Set 12 | nuuk
# Processing Record 34 of Set 12 | constantina
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df =pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          557
# Lat           557
# Lng           557
# Max Temp      557
# Humidity      557
# Cloudiness    557
# Wind Speed    557
# Country       557
# Date          557
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    crystal city  28.6775  -99.8281     25.06        69         100
# 1         susuman  62.7833  148.1667     -3.34        77          89
# 2          bethel  41.3712  -73.4140      9.64        86         100
# 3        hermanus -34.4187   19.2345     16.44        88         100
# 4  yuzhno-kurilsk  44.0306  145.8556      2.43        97         100
#
#    Wind Speed Country        Date
# 0        5.14      US  1713582169
# 1        1.34      RU  1713582219
# 2        1.54      US  1713582457
# 3        0.82      ZA  1713582458
# 4       11.98      RU  1713582458

# %%
# Export the City_Data into a csv
city_data_df.to_csv("..\output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("..\output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0          crystal city  28.6775  -99.8281     25.06        69         100
# 1               susuman  62.7833  148.1667     -3.34        77          89
# 2                bethel  41.3712  -73.4140      9.64        86         100
# 3              hermanus -34.4187   19.2345     16.44        88         100
# 4        yuzhno-kurilsk  44.0306  145.8556      2.43        97         100
#
#          Wind Speed Country        Date
# City_ID
# 0              5.14      US  1713582169
# 1              1.34      RU  1713582219
# 2              1.54      US  1713582457
# 3              0.82      ZA  1713582458
# 4             11.98      RU  1713582458

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
x_axis=city_data_df["Lat"]
y_axis=city_data_df["Max Temp"]
plt.scatter(x_axis,y_axis)

dateintimestamp=city_data_df["Date"].min() #take value of the date that the data was retrieved.
date=time.strftime('%Y-%m-%d',time.gmtime(dateintimestamp))

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")
plt.title(f"City Latitude vs Max Temperature ({date})")

# Save the figure
plt.savefig("../output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
x_axis=city_data_df["Lat"]
y_axis=city_data_df["Humidity"]
plt.scatter(x_axis,y_axis)

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Humidity (%))")
plt.title(f"City Latitude vs Humidity ({date}) ")

# Save the figure
plt.savefig("../output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
x_axis=city_data_df["Lat"]
y_axis=city_data_df["Cloudiness"]
plt.scatter(x_axis,y_axis)

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%))")
plt.title(f"City Latitude vs Cloudiness ({date})")

# Save the figure
plt.savefig("../output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
x_axis=city_data_df["Lat"]
y_axis=city_data_df["Wind Speed"]
plt.scatter(x_axis,y_axis)

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%))")
plt.title(f"City Latitude vs Wind Speed (m/s) ({date})")

# Save the figure
plt.savefig("../output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def plot_linear_regression_line(x_axis,y_axis):
    (slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_axis, y_axis)
    regression_line_eq = f"y = {round(slope, 2)}x + {round(intercept, 2)}"
    regression_values = [slope * x + intercept for x in x_axis]
    plt.plot(x_axis, regression_values, 'r-')
    plt.annotate(regression_line_eq,(min(x_axis), max(y_axis)),fontsize=15,color="red")
    plt.show()
    print(f"the r value is: {rvalue}")

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df=city_data_df[city_data_df["Lat"]>=0]

# Display sample data
northern_hemi_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0          crystal city  28.6775  -99.8281     25.06        69         100
# 1               susuman  62.7833  148.1667     -3.34        77          89
# 2                bethel  41.3712  -73.4140      9.64        86         100
# 4        yuzhno-kurilsk  44.0306  145.8556      2.43        97         100
# 5            whitehorse  60.7161 -135.0538     15.43        14          20
#
#          Wind Speed Country        Date
# City_ID
# 0              5.14      US  1713582169
# 1              1.34      RU  1713582219
# 2              1.54      US  1713582457
# 4             11.98      RU  1713582458
# 5              5.14      CA  1713582203

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df=city_data_df[city_data_df["Lat"]<0]

# Display sample data
southern_hemi_df.head()
# Out:
#                                 City      Lat      Lng  Max Temp  Humidity  \
# City_ID
# 3                           hermanus -34.4187  19.2345     16.44        88
# 6                       puerto ayora  -0.7393 -90.3518     24.19        99
# 9        edinburgh of the seven seas -37.0676 -12.3116     13.73        73
# 10                    otacilio costa -27.4831 -50.1219      9.77        96
# 12                 port-aux-francais -49.3500  70.2167      4.64        69
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 3               100        0.82      ZA  1713582458
# 6                94        1.97      EC  1713582183
# 9               100       12.45      SH  1713582179
# 10                0        1.09      BR  1713582458
# 12               54        7.12      TF  1713582181

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_axis=northern_hemi_df["Lat"]
y_axis=northern_hemi_df["Max Temp"]
plt.scatter(x_axis,y_axis)
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")

plot_linear_regression_line(x_axis,y_axis)
# Out:
# the r value is: -0.8804657249881868

# %%
# Linear regression on Southern Hemisphere
x_axis=southern_hemi_df["Lat"]
y_axis=southern_hemi_df["Max Temp"]
plt.scatter(x_axis,y_axis)
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")

plot_linear_regression_line(x_axis,y_axis)
# Out:
# the r value is: 0.73302600179687

# %% [markdown]
# **Discussion about the linear relationship:** There is a strong correlation btw Latitude and Temperature. The correlation is negative and stronger on the northern hemisphere while it is positive and relatively weaker on the southern hemisphere. Or, temperature is expected to fall when getting away from the equator.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_axis=northern_hemi_df["Lat"]
y_axis=northern_hemi_df["Humidity"]
plt.scatter(x_axis,y_axis)
plt.xlabel("Latitude")
plt.ylabel("Humidity")

plot_linear_regression_line(x_axis,y_axis)
# Out:
# the r value is: 0.12896447466863362

# %%
# Southern Hemisphere
x_axis=southern_hemi_df["Lat"]
y_axis=southern_hemi_df["Humidity"]
plt.scatter(x_axis,y_axis)
plt.xlabel("Latitude")
plt.ylabel("Humidity")

plot_linear_regression_line(x_axis,y_axis)
# Out:
# the r value is: 0.20552711477315946

# %% [markdown]
# **Discussion about the linear relationship:** There is a weak correlation btw Latitude and Humidity based on the r values for both northern and southern hemispheres.Both correlations are positive and one on the northern is slightly stronger.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_axis=northern_hemi_df["Lat"]
y_axis=northern_hemi_df["Cloudiness"]
plt.scatter(x_axis,y_axis)
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")

plot_linear_regression_line(x_axis,y_axis)
# Out:
# the r value is: 0.08684774051343708

# %%
# Southern Hemisphere
x_axis=southern_hemi_df["Lat"]
y_axis=southern_hemi_df["Cloudiness"]
plt.scatter(x_axis,y_axis)
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")

plot_linear_regression_line(x_axis,y_axis)
# Out:
# the r value is: 0.2948977265712107

# %% [raw]
# **Discussion about the linear relationship:** There is a weak positive correlation btw Latitude and Cloudiness on the southern hemisphere whereas there is almost none of correlation btw Latitude and Cloudiness on the northern hemisphere.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_axis=northern_hemi_df["Lat"]
y_axis=northern_hemi_df["Wind Speed"]
plt.scatter(x_axis,y_axis)
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")

plot_linear_regression_line(x_axis,y_axis)
# Out:
# the r value is: 0.1424283173987244

# %%
# Southern Hemisphere
x_axis=southern_hemi_df["Lat"]
y_axis=southern_hemi_df["Wind Speed"]
plt.scatter(x_axis,y_axis)
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")

plot_linear_regression_line(x_axis,y_axis)
# Out:
# the r value is: -0.17047382814774228

# %% [markdown]
# **Discussion about the linear relationship:** There is a weak correlation btw Latitude and Windspeed. The correlative is positve on the northern hemisphere, and negative on the southern hemisphere.
